# %%
#1228 암호문1
for tc in range(1,11):
    N = int(input())
    origin = list(map(int,input().split()))
    M = int(input())
    ins = list(input().split())
    for i in range(len(ins)):
        if ins[i] == 'I':
            index = int(ins[i+1])
            cnt = int(ins[i+2])
            put = ins[i+3:i+4+cnt]
            for j in range(cnt):
                origin.insert(index, put[j])
                index += 1
    print(f'#{tc}',end=' ')
    for i in range(10):
        print(origin[i],end=' ')
    print()

# %%
#1 449047 400905 139831 408347 618608 822798 370982 389953 424216 356268 
#2 150706 600576 565945 486128 594841 566753 244528 233616 556294 697547 
#3 973313 271510 434200 132826 186343 308937 115088 438559 139738 948108 
#4 505428 811504 655028 878767 259061 870009 141255 898646 151553 145048 
#5 267162 670435 488135 605710 353909 276272 171102 871819 129966 404856 
#6 192530 407162 909225 863939 286381 776616 258181 756295 622123 704788 
#7 136752 320395 397751 875871 683248 246614 942192 856739 914031 556177 
#8 482032 518037 497171 841413 364367 572438 104109 354943 999898 765480 
#9 438278 128145 818986 814573 692305 541108 569934 812165 774081 789114 
#10 596308 376463 344210 520543 173961 644251 888643 564430 812181 141946

# %%
#1 449047 400905 139831 408347 512816 992679 693002 835918 768525 949227 
#2 150706 600576 565945 486128 594841 566753 244528 233616 556294 697547 
#3 973313 271510 434200 132826 186343 308937 115088 438559 139738 948108 
#4 505428 811504 426664 713940 855599 655028 878767 259061 870009 141255 
#5 267162 670435 488135 605710 353909 276272 171102 871819 129966 404856 
#6 192530 407162 275094 303667 851080 385930 909225 863939 286381 776616 
#7 136752 320395 397751 875871 683248 246614 942192 856739 914031 556177 
#8 482032 518037 513679 145989 422525 497171 841413 364367 572438 104109 
#9 438278 128145 818986 814573 692305 541108 569934 812165 774081 789114 
#10 596308 376463 344210 520543 173961 644251 888643 787798 136503 153477
# Out:
# ['I',
#  '1',
#  '5',
#  '400905',
#  '139831',
#  '966064',
#  '336948',
#  '119288',
#  'I',
#  '8',
#  '6',
#  '436704',
#  '702451',
#  '762737',
#  '557561',
#  '810021',
#  '771706',
#  'I',
#  '3',
#  '8',
#  '389953',
#  '706628',
#  '552108',
#  '238749',
#  '661021',
#  '498160',
#  '493414',
#  '377808',
#  'I',
#  '13',
#  '4',
#  '237017',
#  '301569',
#  '243869',
#  '252994',
#  'I',
#  '3',
#  '4',
#  '408347',
#  '618608',
#  '822798',
#  '370982',
#  'I',
#  '8',
#  '2',
#  '424216',
#  '356268',
#  'I',
#  '4',
#  '10',
#  '512816',
#  '992679',
#  '693002',
#  '835918',
#  '768525',
#  '949227',
#  '628969',
#  '521945',
#  '839380',
#  '479976']
